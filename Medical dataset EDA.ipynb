# %% [markdown]
# <h1 style="color:green; font-size:30px; font-weight:700; text-align:center">
#     <u><b>Medical dataset EDA</b></u>
# </h1>
#
# <p></p>
# <strong> Author:</strong> Gurtej Bains <br>
# <strong> Data Source:</strong>   <br>
# <strong> Last Updated: </strong>  <br>
# <strong> Problem Statement:</strong> <br>

# %% [markdown]
# <h1 style="color:green"><b>Importing Modules</b> </h1>

# %% [markdown]
# ## Import libraries

# %%
# Numpy
import numpy as np

# Pandas
import pandas as pd

# MatPlotLib
import matplotlib.pyplot as plt

# Seaborn
import seaborn as sns

# scipy
from scipy import stats

# %% [markdown]
# ## Import data

# %%
df = pd.read_csv(r"C:\Users\gurte\OneDrive\All About Learning\Coding Dojo\Learning Material\02 Weekly Assignments\wk16 03-06 (Enrichment, wk3, hypothesis)\medicaldataset-eda\medical_data.csv")
df.columns= df.columns.str.strip().str.lower()
df=df[['vitd_levels', 'doc_visits', 'totalcharge']]
df
# Out:
#      vitd_levels  doc_visits  totalcharge
# 0      19.141466           6  3726.702860
# 1      18.940352           4  4193.190458
# 2      18.057507           4  2434.234222
# 3      16.576858           4  2127.830423
# 4      17.439069           5  2113.073274
# ..           ...         ...          ...
# 995    16.631573           7  2747.196682
# 996    17.810233           6  3661.760740
# 997    17.011913           5  5259.932456
# 998    16.526670           4  3083.731857
# 999    19.487658           7  2830.020820
#
# [1000 rows x 3 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 3 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   vitd_levels  1000 non-null   float64
#  1   doc_visits   1000 non-null   int64
#  2   totalcharge  1000 non-null   float64
# dtypes: float64(2), int64(1)
# memory usage: 23.6 KB

# %% [markdown]
# <h1 style="color:green"><b>EDA: Vitd Levels</b> </h1>

# %% [markdown]
# ## plot

# %%
# column name 
col1 = 'vitd_levels'
feature1 = df[col1]

# calcualtions 
mean = feature1.mean()
median = feature1.median()
std = feature1.std()
plus_one_std = mean + std
minus_one_std = mean - std

# plot 
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x=feature1, kde=False, stat='density')
sns.kdeplot(data=df, x=feature1, ax=ax, color='black')
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', ls='--', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black', label = f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)

ax.set_title(f'{col1}')
ax.legend();

# %%
kurt = stats.kurtosis(feature1, fisher = False)
kurt
# Out:
# 3.013147515833447

# %% [markdown]
# ## interpretation

# %% [markdown]
# This is a continious feature and has a normal distribution. Kurtosis is more than 3 so it is leptokurtic.

# %% [markdown]
# <h1 style="color:green"><b>EDA: Doc Visits</b> </h1>

# %% [markdown]
# ## plot

# %%
# column name 
col2 = 'doc_visits'
feature2 = df[col2]

# calcualtions 
mean = feature2.mean()
median = feature2.median()
std = feature2.std()
plus_one_std = mean + std
minus_one_std = mean - std

# plot 
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x=feature2, discrete=True, kde=False, stat='density')
sns.kdeplot(data=df, x=feature2, ax=ax, color='black')
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', ls='--', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black', label = f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)

ax.set_title(f'{col2}')
ax.legend();

# %%
kurt2 = stats.kurtosis(feature2, fisher = False)
kurt2
# Out:
# 2.9919958083381206

# %% [markdown]
# ## interpretation

# %% [markdown]
# This is a discrete feature and has a normal distribution. Kurtosis is ~3 so it is Mesokurtic.

# %% [markdown]
# <h1 style="color:green"><b>EDA: Total Charge</b> </h1>

# %% [markdown]
# ## plot

# %%
# column name 
col3 = 'totalcharge'
feature3 = df[col3]

# calcualtions 
mean = feature3.mean()
median = feature3.median()
std = feature3.std()
plus_one_std = mean + std
minus_one_std = mean - std

# plot 
fig,ax = plt.subplots(figsize=(10,6))
sns.histplot(data=df, x=feature3, kde=False, stat='density')
sns.kdeplot(data=df, x=feature3, ax=ax, color='black')
ax.axvline(mean, color = 'red', label=f'Mean = {mean:,.2f}')
ax.axvline(median, color = 'green', ls='--', label = f'Median = {median:,.2f}')
ax.axvline(plus_one_std, color = 'black', label = f'+1 std = {plus_one_std:,.2f}')
ax.axvline(minus_one_std, color = 'black', label = f'-1 std = {minus_one_std:,.2f}')
ax.axvspan(plus_one_std, minus_one_std, color = 'yellow', zorder = 0)

ax.set_title(f'{col3}')
ax.legend();

# %%
kurt3 = stats.kurtosis(feature3, fisher = False)
kurt3
# Out:
# 3.2650077463439384

# %% [markdown]
# ## interpretation

# %% [markdown]
# This is a contineous feature and has a positive (right) skew. Kurtosis is more than 3 so it is Leptokurtic.
